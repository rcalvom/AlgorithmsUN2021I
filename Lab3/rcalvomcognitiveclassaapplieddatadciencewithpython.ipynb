# %% [markdown]
# #Lab 3: cognitiveclass.ai Applied Data Science with Python

# %% [markdown]
# ##1. Python 101 for Data Science

# %% [markdown]
# **Link:** https://courses.cognitiveclass.ai/certificates/064d5a56616d43439be3ba739717d9d5

# %% [markdown]
# ## 2. Data Analysis with Python

# %% [markdown]
# **Link:** https://courses.cognitiveclass.ai/certificates/62ec8f536a5a44c1b7f80c4e5757c642

# %% [markdown]
# ## 3. Data Visualization with Python

# %% [markdown]
# **Link:** https://courses.cognitiveclass.ai/certificates/526df82d306e49b384eaab6a34dbc8d7
